# %% [raw]
# ---
# description: Javascript App development
# output-file: react_native.html
# title: React-Native
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# ## Installation

# %% [markdown]
# ```sh
# sudo npm  i -g expo-cli
# ```

# %% [markdown]
# **Install expo app**

# %% [markdown]
# ## Starting a new project

# %% [markdown]
# ```sh
# expo init DoneWithIt
# ```
