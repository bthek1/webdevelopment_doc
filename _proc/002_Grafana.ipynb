# %% [raw]
# ---
# description: Timeseries frontend
# output-file: grafana.html
# title: Grafana
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# ## Installation

# %% [markdown]
# ```sh
# sudo apt-get install -y adduser libfontconfig1 musl
# wget https://dl.grafana.com/enterprise/release/grafana-enterprise_10.2.0_amd64.deb
# sudo dpkg -i grafana-enterprise_10.2.0_amd64.deb
# ```

# %% [markdown]
# ## To Start Grafana Server

# %% [markdown]
# ```sh
# sudo systemctl start grafana-server
# ```

# %% [markdown]
# ## To get Grafana Server status

# %% [markdown]
# ```sh
# sudo systemctl status grafana-server
# ```

# %% [markdown]
# ## To Stop Grafana server

# %% [markdown]
# ```sh
# sudo systemctl stop grafana-server
# ```

# %% [markdown]
# ## LocalHost Port

# %% [markdown]
# ```sh
# http://localhost:3000
# ```
